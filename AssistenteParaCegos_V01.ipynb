# %% [markdown]
# <a href="https://colab.research.google.com/github/Mario-Henrique/AssistenteParaCegos/blob/main/AssistenteParaCegos_V01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Realiza a instalação do pacote de ia do Google

# %%
# !pip install -q -U google-generativeai

# %% [markdown]
# Importar o SDK do Python e configurar a API_KEY

# %%
import google.generativeai as genai
from google.colab import userdata

GEMINI_API_KEY = userdata.get('GEMINI_API_KEY')
genai.configure(api_key=GEMINI_API_KEY)

# %% [markdown]
# Para saber quais os modelos disponíveis para uso então vamos listar todos.

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %% [markdown]
# Determinar parâmetros de configuração do nosso modelo.

# %%
generation_config = {
    "candidate_count": 1,
    "temperature": 0.25
}

# %% [markdown]
# Inicializar o modelo que será utilizado.

# %%
model = genai.GenerativeModel(model_name="gemini-pro",
                              generation_config=generation_config)

# %%
response = model.generate_content("Qual o seu nome?")
assistente_response = response.text

# %% [markdown]
# Instalação do gTTS para sintetização do texto em voz

# %%
# !pip install gTTS

# %% [markdown]
# Configuração do gTTS e criação do arquivo de audio com a resposta do Gemini

# %%
from gtts import gTTS

taxa_fala = 1.5

gtts_object = gTTS(assistente_response, lang='pt')

response_audio = "/content/response_audio.mp3"
gtts_object.save(response_audio)

# %% [markdown]
# Instalação do pysoundfile para execução do audio

# %%
# !pip install pysoundfile

# %% [markdown]
# Importando a biblioteca IPython e tocando o aúdio.

# %%
import IPython
IPython.display.Audio(response_audio, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
